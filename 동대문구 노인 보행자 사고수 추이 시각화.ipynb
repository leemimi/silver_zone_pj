# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
accidentdata = pd.read_csv('노인보행자사고수년도별.csv',encoding='euc-kr')
accidentdata
# Out:
#      년도  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0    소계  1467  1630  1664  1704  1857  2002  2141  2331  2266  2274  2289
# 1  동대문구    81    92   107    88   119   129   134   146   160   139   149
#
#    2019  2020  2021
# 0  2303  1826  1743
# 1   136   129   115

# %%
data=accidentdata.loc[1]

adata=pd.DataFrame(data)
adata.columns=['소계']

adata
# Out:
#         소계
# 년도    동대문구
# 2008    81
# 2009    92
# 2010   107
# 2011    88
# 2012   119
# 2013   129
# 2014   134
# 2015   146
# 2016   160
# 2017   139
# 2018   149
# 2019   136
# 2020   129
# 2021   115

# %%
adata.reset_index(inplace=True)

adata.drop(0, inplace=True)

adata
# Out:
#    index   소계
# 1   2008   81
# 2   2009   92
# 3   2010  107
# 4   2011   88
# 5   2012  119
# 6   2013  129
# 7   2014  134
# 8   2015  146
# 9   2016  160
# 10  2017  139
# 11  2018  149
# 12  2019  136
# 13  2020  129
# 14  2021  115

# %%
adata.rename(columns={'index':'년도'},inplace=True)
adata.rename(columns={'소계':'합계'},inplace=True)

# %%
adata
# Out:
#       년도   합계
# 1   2008   81
# 2   2009   92
# 3   2010  107
# 4   2011   88
# 5   2012  119
# 6   2013  129
# 7   2014  134
# 8   2015  146
# 9   2016  160
# 10  2017  139
# 11  2018  149
# 12  2019  136
# 13  2020  129
# 14  2021  115

# %%
adata = adata.apply(pd.to_numeric)
adata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 1 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      14 non-null     int64
#  1   합계      14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
adata.to_csv('노인보행교통사고.csv', encoding='utf-8')

# %%
ax = adata.plot(x='년도', y='합계', figsize=(14,7), rot=0, color='r')
plt.title('노인 동대문구 보행자 교통사고 추이',size=15)
plt.xlabel('년도', fontsize=15)
plt.ylabel('합계',fontsize=15)

for temp in ax.patches:
    ax.annotate('%d'%temp.get_height(),(temp.get_x()+temp.get_width()/2, temp.get_height()), ha='center',va='bottom')
plt.show()
